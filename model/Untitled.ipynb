# %%
from ib_insync import *
import pandas as pd
import numpy as np
import joblib
import schedule
import time

# %%
ib = IB()
ib.connect('192.168.1.4', 7497, clientId=66)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 2
#       1 ib = IB()
# ----> 2 ib.connect('192.168.1.4', 7497, clientId=1)
#
# File ~/local/arh_venv/lib/python3.12/site-packages/ib_insync/ib.py:279, in IB.connect(self, host, port, clientId, timeout, readonly, account)
#     257 def connect(
#     258         self, host: str = '127.0.0.1', port: int = 7497, clientId: int = 1,
#     259         timeout: float = 4, readonly: bool = False, account: str = ''):
#     260     """
#     261     Connect to a running TWS or IB gateway application.
#     262     After the connection is made the client is fully synchronized
#    (...)    277         account: Main account to receive updates for.
#     278     """
# --> 279     return self._run(self.connectAsync(
#     280         host, port, clientId, timeout, readonly, account))
#
# ...
