# %%
def generate_key(msg, key):
    key = list(key)
    if len(msg) == len(key):
        return key
    else:
        for i in range(len(msg) - len(key)):
            key.append(key[i % len(key)])
    return "".join(key)

def encrypt_vigenere(msg, key):
    encrypted_text = []
    key = generate_key(msg, key)
    for i in range(len(msg)):
        char = msg[i]
        if char.isupper():
            encrypted_char = chr((ord(char) + ord(key[i]) - 2 * ord('A')) % 26 + ord('A'))
        elif char.islower():
            encrypted_char = chr((ord(char) + ord(key[i]) - 2 * ord('a')) % 26 + ord('a'))
        else:
            encrypted_char = char
        encrypted_text.append(encrypted_char)
    return "".join(encrypted_text)

def decrypt_vigenere(msg, key):
    decrypted_text = []
    key = generate_key(msg, key)
    for i in range(len(msg)):
        char = msg[i]
        if char.isupper():
            decrypted_char = chr((ord(char) - ord(key[i]) + 26) % 26 + ord('A'))
        elif char.islower():
            decrypted_char = chr((ord(char) - ord(key[i]) + 26) % 26 + ord('a'))
        else:
            decrypted_char = char
        decrypted_text.append(decrypted_char)
    return "".join(decrypted_text)

# Example usage
text_to_encrypt = "theclassistough"
key = "apple"

encrypted_text = encrypt_vigenere(text_to_encrypt, key)
print(f"Encrypted Text: {encrypted_text}")

decrypted_text = decrypt_vigenere(encrypted_text, key)
print(f"Decrypted Text: {decrypted_text}")
# Out:
# Encrypted Text: twtnpahhtwtdjrl
# Decrypted Text: theclassistough

# %%
# -----------------------------------------------
# encrypt_affine
#
# INPUT
# text - string being encrypted
# key - values of [a, b]
#
# OUTPUT
# cyphertext
# ----------------------------------------------
def encrypt_affine(text, key):
    #C = (a*P + b) % 26
    return ''.join([ chr((( key[0]*(ord(t) - ord('A')) + key[1] ) % 26) 
                  + ord('A')) for t in text.upper().replace(' ', '') ])

# -----------------------------------------------
# decrypt_affine
#
# INPUT
# cipher - encrypted text
# key - values of [a, b]
#
# OUTPUT
# plaintext
# ----------------------------------------------
def decrypt_affine(cipher, key):
    #P = (a^-1 * (C - b)) % 26
    return ''.join([ chr((( pow(key[0], -1, 26)*(ord(c) - ord('A') - key[1])) 
                    % 26) + ord('A')) for c in cipher ])


## Q2B

text = 'CRYPTOISFUN'
key = [5, 9]

affine_cipher_text = encrypt_affine(text, key)
print('Text       : {}'.format(text))
print('Ciphertext : {}'.format(affine_cipher_text))
print('Plaintext  : {}\n'.format(decrypt_affine(affine_cipher_text, key)))

## Q2C
text = 'QJKESREOGHGXXREOXEO'
key = [11, 6]
# Decrypt
print('Ciphertext : {}'.format(text))
print('Plaintext  : {}'.format(decrypt_affine(text, key)))
# Out:
# Text       : CRYPTOISFUN
# Ciphertext : TQZGABXVIFW
# Plaintext  : CRYPTOISFUN
#
# Ciphertext : QJKESREOGHGXXREOXEO
# Plaintext  : IFYOUBOWATALLBOWLOW
